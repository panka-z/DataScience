# %% [markdown]
# <a href="https://colab.research.google.com/github/panka-z/DataScience/blob/master/resume_summary_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
#' ' means CPU whereas '/device:G:0' means GPU
import tensorflow as tf
tf.test.gpu_device_name()

# memory footprint support libraries/code

# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Collecting gputil
#   Downloading https://files.pythonhosted.org/packages/ed/0e/5c61eedde9f6c87713e89d794f01e378cfd9565847d4576fa627d758c554/GPUtil-1.4.0.tar.gz
# Building wheels for collected packages: gputil
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-cp36-none-any.whl size=7410 sha256=842ba6990d410fea138596cbdefa7139bf1cec16a6e9abefbfe828ca1c134be3
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.4.0
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (5.4.8)
# Requirement already satisfied: humanize in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Gen RAM Free: 11.8 GB  | Proc size: 2.2 GB
# GPU RAM Free: 11120MB | Used: 321MB | Util   3% | Total 11441MB

# %%
resume_count=len(list(open(filepath,'r',encoding="utf8").readlines()))
print('Total available resumes => ',resume_count)
# Out:
# Total available resumes =>  701

# %%
#------------imports ---------------------------------
from __future__ import unicode_literals, print_function
import json
import pprint
import re
import plac
import random
from pathlib import Path
import spacy
import time
from spacy.util import minibatch, compounding

#--------------initial setup ------------------------------

# # uploading local files onto colab
# from google.colab import files
# uploaded = files.upload()

# #Mounting google drive into colab
#from google.colab import drive
#drive.mount('/content/gdrive')

# with open("gdrive/My Drive/Demo Document Annotations1.json",'rb') as f:
  # for line in f:
	# print(line)

start_time = time.time()

#debug variable
temp=[]

# file path from mounted gdrive
#filepath="gdrive/My Drive/Demo Document Annotations.json"
filepath="gdrive/My Drive/Entity Recognition in Resumes.json"
output_dir="gdrive/My Drive/NLP_Model/"

#filepath="C:/Users/User/Downloads/Demo Document Annotations.json"
#output_dir="C:\Suven\AdvML\Resume_Summarisation_Project"

# training data
TRAIN_DATA = [
	("Who is Shaka Khan? , I am Pankaj", {"entities": [(7, 17, "PERSON"),(26, 32, "PERSON")]}),
	("I like London and Berlin.", {"entities": [(7, 13, "LOC"), (18, 24, "LOC")]}),
]

TEST_DATA = [
	("I am Peter",{}),
	("I like Mumbai and Calcutta",{})
]

TRAIN_DATA[0][0][26:32]
	
training_data = []	
resume_count=len(list(open(filepath,'r',encoding="utf8").readlines()))
print('Total available resumes => ',resume_count)

#------------------------------------------------------
	

def load_data():
	print('loading training data ...')
	lines=open(filepath,'r',encoding="utf8").readlines()	
	for i,line in enumerate(lines):
		# if i>440:
			# break
		data = json.loads(line)
		text = data['content']
		entities = []
		if data['annotation']:
			for annotation in data['annotation']:
				#only a single point in text annotation.
				point = annotation['points'][0]
				labels = [ str(i).upper() for i in annotation['label']]
				#print(labels)
				# handle both list of labels or a single label.
				if not isinstance(labels, list):
					labels = [labels]

				for label in labels:
					#dataturks indices are both inclusive [start, end] but spacy is not [start, end)
					entities.append((point['start'], point['end'] + 1 ,label))

			training_data.append((text, {"entities" : entities}))
	print('loaded training data ...')


	
def loadmodel(model=None, output_dir=None, n_iter=100):
    """Load the model, set up the pipeline and train the entity recognizer."""
    print('loading the model ...')
    if model is not None:
        nlp = spacy.load(model)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank("en")  # create blank Language class
        print("Created blank 'en' model")

    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner, last=True)
    # otherwise, get it so we can add labels
    else:
        ner = nlp.get_pipe("ner")

    # add labels
    for _, annotations in TRAIN_DATA:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
    with nlp.disable_pipes(*other_pipes):  # only train NER
        # reset and initialize the weights randomly – but only if we're
        # training a new model
        if model is None:
            nlp.begin_training()
        for itn in range(n_iter):
            random.shuffle(TRAIN_DATA)
            losses = {}
            # batch up the examples using spaCy's minibatch
            batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
            for batch in batches:
                texts, annotations = zip(*batch)
                try:
                  nlp.update(
                      texts,  # batch of texts
                      annotations,  # batch of annotations
                      drop=0.3,  # dropout - make it harder to memorise data
                      losses=losses
                  )
                except Exception as e:
                  temp.append(texts)
                  #print('Exception in => ',texts)
                  #print('Error is => ',str(e),'\n')
                  continue
            if losses:  
                print("losses ",losses)

    # ---------test the trained model ------------------
    
    print('+'*140)
    print('testing the trained model ','\n')

    for text, _ in TRAIN_DATA:
        doc = nlp(text)
        #pprint.pprint(doc.ents)
        print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
        print('_'*100)
        print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc if t.ent_type_])
        print('_'*100)

    # ---- save model to output directory --------------
    if output_dir is not None:
        output_dir = Path(output_dir)
        if not output_dir.exists():
            output_dir.mkdir()
        nlp.meta["name"] = "resume_summ"  # rename model
        nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

        # test the saved model
        print("Loading from", output_dir)
        nlp2 = spacy.load(output_dir)
        # Check the classes have loaded back consistently
        assert nlp2.get_pipe("ner").move_names == list(ner.move_names)
        doc2 = nlp2(TRAIN_DATA[random.randrange(10)][0])
        #pprint.pprint(doc2)
        print('Predicted entities > ','\n')
        for ent in doc2.ents:
            print(ent.label_, ent.text)
        print('\n')

#------- Main program begins ---------------------------	
#if __name__ =='__main__':	

load_data()
TRAIN_DATA=training_data
temp.clear()
loadmodel(output_dir=output_dir)

print('# of resumes failed to be parsed =>',len(temp))
print('+'*100)

# for t,a in training_data:
  # for an in a['entities']:
    # print(an[2],'=>',t[an[0]:an[1]])

  # print('-'*100)
  # break

elapsed_time = time.time() - start_time
print('\n')
print('Execution completed in => ',time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# Total available resumes =>  701
# loading training data ...
# loaded training data ...
# loading the model ...
# Created blank 'en' model
# losses  {'ner': 61631.355888613034}
# losses  {'ner': 57015.14715683175}
# losses  {'ner': 43290.91302209247}
# losses  {'ner': 35223.443659289434}
# losses  {'ner': 30685.453033639533}
# losses  {'ner': 27645.921243156496}
# losses  {'ner': 26742.21234035261}
# losses  {'ner': 25267.657598581587}
# losses  {'ner': 22849.03277149885}
# losses  {'ner': 22954.341208692524}
# losses  {'ner': 21820.938929965647}
# losses  {'ner': 22073.724806090537}
# losses  {'ner': 21467.039941272866}
# losses  {'ner': 23250.556625258363}
# losses  {'ner': 20588.724185167805}
# losses  {'ner': 21010.33881678484}
# losses  {'ner': 20857.46214864325}
# losses  {'ner': 20092.654317561588}
# losses  {'ner': 20240.68887864492}
# losses  {'ner': 19197.549139953888}
# losses  {'ner': 19882.17465196555}
# losses  {'ner': 18091.615836353732}
# losses  {'ner': 18237.632641868204}
# losses  {'ner': 18592.257356498347}
# losses  {'ner': 17041.118337380398}
# losses  {'ner': 18603.062266023873}
# losses  {'ner': 19173.411201169394}
# losses  {'ner': 16580.07032394357}
# losses  {'ner': 19263.776258497237}
# losses  {'ner': 17737.182038827646}
# losses  {'ner': 17251.49450164623}
# losses  {'ner': 17955.093938427024}
# losses  {'ner': 16773.400471201647}
# losses  {'ner': 16021.248876873467}
# losses  {'ner': 15240.8962577991}
# losses  {'ner': 15535.710607566883}
# losses  {'ner': 15525.755152422948}
# losses  {'ner': 15389.715596066566}
# losses  {'ner': 15943.572887454899}
# losses  {'ner': 14549.023107589112}
# losses  {'ner': 15186.059264074853}
# losses  {'ner': 14738.363957910027}
# losses  {'ner': 14424.325847975513}
# losses  {'ner': 14094.846144829948}
# losses  {'ner': 14148.158068283237}
# losses  {'ner': 14692.918342892553}
# losses  {'ner': 14883.214408934016}
# losses  {'ner': 14650.845066672022}
# losses  {'ner': 13762.351130282479}
# losses  {'ner': 13964.985137624037}
# losses  {'ner': 14123.348159587787}
# losses  {'ner': 12542.336127572817}
# losses  {'ner': 13029.635439166184}
# losses  {'ner': 13808.672641580064}
# losses  {'ner': 13256.081512694891}
# losses  {'ner': 13582.88090643915}
# losses  {'ner': 13395.137574513843}
# losses  {'ner': 13507.463327489695}
# losses  {'ner': 13863.224866474522}
# losses  {'ner': 12920.535817890883}
# losses  {'ner': 13261.782614851783}
# losses  {'ner': 12297.35286873951}
# losses  {'ner': 11801.00674311141}
# losses  {'ner': 11983.2966347521}
# losses  {'ner': 12748.446262697793}
# losses  {'ner': 12278.900678617663}
# losses  {'ner': 12426.690761616721}
# losses  {'ner': 11645.918112681302}
# losses  {'ner': 11741.461468093547}
# losses  {'ner': 11754.325511315741}
# losses  {'ner': 11967.913236044074}
# losses  {'ner': 12103.081998223175}
# losses  {'ner': 11605.72721521209}
# losses  {'ner': 11779.78781824624}
# losses  {'ner': 10812.206292101268}
# losses  {'ner': 11302.116368619341}
# losses  {'ner': 12179.474065253911}
# losses  {'ner': 12162.979314988876}
# losses  {'ner': 10384.175265147807}
# losses  {'ner': 11833.670360479031}
# losses  {'ner': 11534.59444708659}
# losses  {'ner': 11260.76889819051}
# losses  {'ner': 11099.221769398213}
# losses  {'ner': 12070.187499891304}
# losses  {'ner': 10953.759194615246}
# losses  {'ner': 11059.822565657416}
# losses  {'ner': 10762.347374782761}
# losses  {'ner': 10592.34964572714}
# losses  {'ner': 10468.778183800096}
# losses  {'ner': 9723.82812787118}
# losses  {'ner': 9874.548980680389}
# losses  {'ner': 10230.539372215737}
# losses  {'ner': 9975.447035312427}
# losses  {'ner': 10626.662652086288}
# losses  {'ner': 10132.339117115514}
# losses  {'ner': 10444.555779059312}
# losses  {'ner': 9760.416655044948}
# losses  {'ner': 10023.253410555002}
# losses  {'ner': 9773.008432668083}
# losses  {'ner': 9332.67802671192}
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# testing the trained model
#
# Entities [('Rajesh Rokaya', 'NAME'), ('Sales', 'DESIGNATION'), ('Mumbai', 'LOCATION'), ('indeed.com/r/Rajesh-Rokaya/51899dfb8f972708', 'EMAIL ADDRESS'), ('Sales', 'DESIGNATION'), ('Kotak Mahindra Bank', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('July 2013 to August 2014', 'YEARS OF EXPERIENCE'), ('positive', 'UNKNOWN'), ('Hard working', 'SKILLS'), ('dedicative to my job, regularity and self confidence', 'SKILLS'), ('B.com in Commerce', 'DEGREE'), ('Lords Universal College', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('positive', 'UNKNOWN'), ('hard working', 'SKILLS'), ('self confidence', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('Rajesh', 'NAME', 3), ('Rokaya', 'NAME', 1), ('Sales', 'DESIGNATION', 3), ('Mumbai', 'LOCATION', 3), ('indeed.com/r/Rajesh-Rokaya/51899dfb8f972708', 'EMAIL ADDRESS', 3), ('Sales', 'DESIGNATION', 3), ('Kotak', 'COMPANIES WORKED AT', 3), ('Mahindra', 'COMPANIES WORKED AT', 1), ('Bank', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('July', 'YEARS OF EXPERIENCE', 3), ('2013', 'YEARS OF EXPERIENCE', 1), ('to', 'YEARS OF EXPERIENCE', 1), ('August', 'YEARS OF EXPERIENCE', 1), ('2014', 'YEARS OF EXPERIENCE', 1), ('positive', 'UNKNOWN', 3), ('Hard', 'SKILLS', 3), ('working', 'SKILLS', 1), ('dedicative', 'SKILLS', 3), ('to', 'SKILLS', 1), ('my', 'SKILLS', 1), ('job', 'SKILLS', 1), (',', 'SKILLS', 1), ('regularity', 'SKILLS', 1), ('and', 'SKILLS', 1), ('self', 'SKILLS', 1), ('confidence', 'SKILLS', 1), ('B.com', 'DEGREE', 3), ('in', 'DEGREE', 1), ('Commerce', 'DEGREE', 1), ('Lords', 'COMPANIES WORKED AT', 3), ('Universal', 'COMPANIES WORKED AT', 1), ('College', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('positive', 'UNKNOWN', 3), ('hard', 'SKILLS', 3), ('working', 'SKILLS', 1), ('self', 'SKILLS', 3), ('confidence', 'SKILLS', 1)]
# ____________________________________________________________________________________________________
# Entities [('Navas Koya', 'NAME'), ('Test Engineer', 'DESIGNATION'), ('Mangalore', 'LOCATION'), ('Mangalore', 'LOCATION'), ('System Engineer', 'DESIGNATION'), ('Infosys', 'COMPANIES WORKED AT'), ('Test Engineer', 'DESIGNATION'), ('Infosys', 'COMPANIES WORKED AT'), ('Infosys Limited', 'COMPANIES WORKED AT'), ('2014', 'GRADUATION YEAR'), ('2015', 'GRADUATION YEAR'), ('Software Test Executive\n', 'DESIGNATION'), ('Bachelor of Computer Applications', 'DEGREE'), ('Mangalore', 'LOCATION'), ('Mangalore', 'LOCATION'), ('2014', 'GRADUATION YEAR'), ('C# (Less than 1 year), .NET, SQL Server, Css, Html5\n\nADDITIONAL INFORMATION\n\nBachelor of computer application: with 74% from Milagres College, Kallianpur under\nMangalore University, Karnataka.', 'SKILLS'), ('SKILL SET • ASP.NET, C# • QA tools\n\n• Coding and modularization • Excellent communication skills\n\n• VB, VB.net, ASP • Technical specifications creation\n\n• HTML • System backups\n\n• Sql server 2005, Oracle • System upgrades\n\n• Java/C/C++ • Excellent problem-solving abilities\n\nNavas Najeer Koya 3', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('Navas', 'NAME', 3), ('Koya', 'NAME', 1), ('Test', 'DESIGNATION', 3), ('Engineer', 'DESIGNATION', 1), ('Mangalore', 'LOCATION', 3), ('Mangalore', 'LOCATION', 3), ('System', 'DESIGNATION', 3), ('Engineer', 'DESIGNATION', 1), ('Infosys', 'COMPANIES WORKED AT', 3), ('Test', 'DESIGNATION', 3), ('Engineer', 'DESIGNATION', 1), ('Infosys', 'COMPANIES WORKED AT', 3), ('Infosys', 'COMPANIES WORKED AT', 3), ('Limited', 'COMPANIES WORKED AT', 1), ('2014', 'GRADUATION YEAR', 3), ('2015', 'GRADUATION YEAR', 3), ('Software', 'DESIGNATION', 3), ('Test', 'DESIGNATION', 1), ('Executive', 'DESIGNATION', 1), ('\n', 'DESIGNATION', 1), ('Bachelor', 'DEGREE', 3), ('of', 'DEGREE', 1), ('Computer', 'DEGREE', 1), ('Applications', 'DEGREE', 1), ('Mangalore', 'LOCATION', 3), ('Mangalore', 'LOCATION', 3), ('2014', 'GRADUATION YEAR', 3), ('C', 'SKILLS', 3), ('#', 'SKILLS', 1), ('(', 'SKILLS', 1), ('Less', 'SKILLS', 1), ('than', 'SKILLS', 1), ('1', 'SKILLS', 1), ('year', 'SKILLS', 1), (')', 'SKILLS', 1), (',', 'SKILLS', 1), ('.NET', 'SKILLS', 1), (',', 'SKILLS', 1), ('SQL', 'SKILLS', 1), ('Server', 'SKILLS', 1), (',', 'SKILLS', 1), ('Css', 'SKILLS', 1), (',', 'SKILLS', 1), ('Html5', 'SKILLS', 1), ('\n\n', 'SKILLS', 1), ('ADDITIONAL', 'SKILLS', 1), ('INFORMATION', 'SKILLS', 1), ('\n\n', 'SKILLS', 1), ('Bachelor', 'SKILLS', 1), ('of', 'SKILLS', 1), ('computer', 'SKILLS', 1), ('application', 'SKILLS', 1), (':', 'SKILLS', 1), ('with', 'SKILLS', 1), ('74', 'SKILLS', 1), ('%', 'SKILLS', 1), ('from', 'SKILLS', 1), ('Milagres', 'SKILLS', 1), ('College', 'SKILLS', 1), (',', 'SKILLS', 1), ('Kallianpur', 'SKILLS', 1), ('under', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('Mangalore', 'SKILLS', 1), ('University', 'SKILLS', 1), (',', 'SKILLS', 1), ('Karnataka', 'SKILLS', 1), ('.', 'SKILLS', 1), ('SKILL', 'SKILLS', 3), ('SET', 'SKILLS', 1), ('•', 'SKILLS', 1), ('ASP.NET', 'SKILLS', 1), (',', 'SKILLS', 1), ('C', 'SKILLS', 1), ('#', 'SKILLS', 1), ('•', 'SKILLS', 1), ('QA', 'SKILLS', 1), ('tools', 'SKILLS', 1), ('\n\n', 'SKILLS', 1), ('•', 'SKILLS', 1), ('Coding', 'SKILLS', 1), ('and', 'SKILLS', 1), ('modularization', 'SKILLS', 1), ('•', 'SKILLS', 1), ('Excellent', 'SKILLS', 1), ('communication', 'SKILLS', 1), ('skills', 'SKILLS', 1), ('\n\n', 'SKILLS', 1), ('•', 'SKILLS', 1), ('VB', 'SKILLS', 1), (',', 'SKILLS', 1), ('VB.net', 'SKILLS', 1), (',', 'SKILLS', 1), ('ASP', 'SKILLS', 1), ('•', 'SKILLS', 1), ('Technical', 'SKILLS', 1), ('specifications', 'SKILLS', 1), ('creation', 'SKILLS', 1), ('\n\n', 'SKILLS', 1), ('•', 'SKILLS', 1), ('HTML', 'SKILLS', 1), ('•', 'SKILLS', 1), ('System', 'SKILLS', 1), ('backups', 'SKILLS', 1), ('\n\n', 'SKILLS', 1), ('•', 'SKILLS', 1), ('Sql', 'SKILLS', 1), ('server', 'SKILLS', 1), ('2005', 'SKILLS', 1), (',', 'SKILLS', 1), ('Oracle', 'SKILLS', 1), ('•', 'SKILLS', 1), ('System', 'SKILLS', 1), ('upgrades', 'SKILLS', 1), ('\n\n', 'SKILLS', 1), ('•', 'SKILLS', 1), ('Java', 'SKILLS', 1), ('/', 'SKILLS', 1), ('C', 'SKILLS', 1), ('/', 'SKILLS', 1), ('C++', 'SKILLS', 1), ('•', 'SKILLS', 1), ('Excellent', 'SKILLS', 1), ('problem', 'SKILLS', 1), ('-', 'SKILLS', 1), ('solving', 'SKILLS', 1), ('abilities', 'SKILLS', 1), ('\n\n', 'SKILLS', 1), ('Navas', 'SKILLS', 1), ('Najeer', 'SKILLS', 1), ('Koya', 'SKILLS', 1), ('3', 'SKILLS', 1)]
# ____________________________________________________________________________________________________
# Entities [('Prabhu Prasad Mohapatra', 'NAME'), ('Bhubaneswar', 'LOCATION'), ('indeed.com/r/Prabhu-Prasad-\nMohapatra/1e4b62ea17458993', 'EMAIL ADDRESS'), ('Beta Tester', 'DESIGNATION'), ('Microsoft & Xiaomi', 'COMPANIES WORKED AT'), ('Still Studying', 'DEGREE'), ('Bhagabati Nodal High School', 'COLLEGE NAME')]
# ____________________________________________________________________________________________________
# Tokens [('Prabhu', 'NAME', 3), ('Prasad', 'NAME', 1), ('Mohapatra', 'NAME', 1), ('Bhubaneswar', 'LOCATION', 3), ('indeed.com', 'EMAIL ADDRESS', 3), ('/', 'EMAIL ADDRESS', 1), ('r', 'EMAIL ADDRESS', 1), ('/', 'EMAIL ADDRESS', 1), ('Prabhu', 'EMAIL ADDRESS', 1), ('-', 'EMAIL ADDRESS', 1), ('Prasad-', 'EMAIL ADDRESS', 1), ('\n', 'EMAIL ADDRESS', 1), ('Mohapatra/1e4b62ea17458993', 'EMAIL ADDRESS', 1), ('Beta', 'DESIGNATION', 3), ('Tester', 'DESIGNATION', 1), ('Microsoft', 'COMPANIES WORKED AT', 3), ('&', 'COMPANIES WORKED AT', 1), ('Xiaomi', 'COMPANIES WORKED AT', 1), ('Still', 'DEGREE', 3), ('Studying', 'DEGREE', 1), ('Bhagabati', 'COLLEGE NAME', 3), ('Nodal', 'COLLEGE NAME', 1), ('High', 'COLLEGE NAME', 1), ('School', 'COLLEGE NAME', 1)]
# ____________________________________________________________________________________________________
# Entities [('Bipul Poddar', 'NAME'), ('Sales Manager', 'DESIGNATION'), ('Wings Life Spaces Marketing Services Pvt Ltd', 'COMPANIES WORKED AT'), ('Navi Mumbai', 'LOCATION'), ('indeed.com/r/Bipul-Poddar/\nbc91d88e3136309a', 'EMAIL ADDRESS'), ('8 years of experience', 'YEARS OF EXPERIENCE'), ('Sales Manager', 'DESIGNATION'), ('Wings Life Spaces Marketing Services Pvt Ltd', 'COMPANIES WORKED AT'), ('Disha Direct Marketing Services Pvt Ltd.', 'COMPANIES WORKED AT'), ('2 years.', 'YEARS OF EXPERIENCE'), ('Manager Sales.', 'DESIGNATION'), ('Avani Realtors Pvt Ltd.', 'COMPANIES WORKED AT'), ('2.5 years', 'YEARS OF EXPERIENCE'), ('Sales Manager', 'DESIGNATION'), ('RELIANCE INFOCOM LTD.', 'COMPANIES WORKED AT'), ('3years.', 'YEARS OF EXPERIENCE'), ('Sales Associates Executive.', 'DESIGNATION'), ('Sales Manager', 'DESIGNATION'), ('Disha Direct Marketing Services Pvt Ltd.', 'COMPANIES WORKED AT'), ('Bachelor of Arts in Political Science', 'DEGREE'), ('Kolkata University', 'COLLEGE NAME'), ('Sales Manager', 'SKILLS'), ('Real Estate', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('Bipul', 'NAME', 3), ('Poddar', 'NAME', 1), ('Sales', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('Wings', 'COMPANIES WORKED AT', 3), ('Life', 'COMPANIES WORKED AT', 1), ('Spaces', 'COMPANIES WORKED AT', 1), ('Marketing', 'COMPANIES WORKED AT', 1), ('Services', 'COMPANIES WORKED AT', 1), ('Pvt', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('Navi', 'LOCATION', 3), ('Mumbai', 'LOCATION', 1), ('indeed.com/r/Bipul-Poddar/', 'EMAIL ADDRESS', 3), ('\n', 'EMAIL ADDRESS', 1), ('bc91d88e3136309a', 'EMAIL ADDRESS', 1), ('8', 'YEARS OF EXPERIENCE', 3), ('years', 'YEARS OF EXPERIENCE', 1), ('of', 'YEARS OF EXPERIENCE', 1), ('experience', 'YEARS OF EXPERIENCE', 1), ('Sales', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('Wings', 'COMPANIES WORKED AT', 3), ('Life', 'COMPANIES WORKED AT', 1), ('Spaces', 'COMPANIES WORKED AT', 1), ('Marketing', 'COMPANIES WORKED AT', 1), ('Services', 'COMPANIES WORKED AT', 1), ('Pvt', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('Disha', 'COMPANIES WORKED AT', 3), ('Direct', 'COMPANIES WORKED AT', 1), ('Marketing', 'COMPANIES WORKED AT', 1), ('Services', 'COMPANIES WORKED AT', 1), ('Pvt', 'COMPANIES WORKED AT', 1), ('Ltd.', 'COMPANIES WORKED AT', 1), ('2', 'YEARS OF EXPERIENCE', 3), ('years', 'YEARS OF EXPERIENCE', 1), ('.', 'YEARS OF EXPERIENCE', 1), ('Manager', 'DESIGNATION', 3), ('Sales', 'DESIGNATION', 1), ('.', 'DESIGNATION', 1), ('Avani', 'COMPANIES WORKED AT', 3), ('Realtors', 'COMPANIES WORKED AT', 1), ('Pvt', 'COMPANIES WORKED AT', 1), ('Ltd.', 'COMPANIES WORKED AT', 1), ('2.5', 'YEARS OF EXPERIENCE', 3), ('years', 'YEARS OF EXPERIENCE', 1), ('Sales', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('RELIANCE', 'COMPANIES WORKED AT', 3), ('INFOCOM', 'COMPANIES WORKED AT', 1), ('LTD', 'COMPANIES WORKED AT', 1), ('.', 'COMPANIES WORKED AT', 1), ('3years', 'YEARS OF EXPERIENCE', 3), ('.', 'YEARS OF EXPERIENCE', 1), ('Sales', 'DESIGNATION', 3), ('Associates', 'DESIGNATION', 1), ('Executive', 'DESIGNATION', 1), ('.', 'DESIGNATION', 1), ('Sales', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('Disha', 'COMPANIES WORKED AT', 3), ('Direct', 'COMPANIES WORKED AT', 1), ('Marketing', 'COMPANIES WORKED AT', 1), ('Services', 'COMPANIES WORKED AT', 1), ('Pvt', 'COMPANIES WORKED AT', 1), ('Ltd.', 'COMPANIES WORKED AT', 1), ('Bachelor', 'DEGREE', 3), ('of', 'DEGREE', 1), ('Arts', 'DEGREE', 1), ('in', 'DEGREE', 1), ('Political', 'DEGREE', 1), ('Science', 'DEGREE', 1), ('Kolkata', 'COLLEGE NAME', 3), ('University', 'COLLEGE NAME', 1), ('Sales', 'SKILLS', 3), ('Manager', 'SKILLS', 1), ('Real', 'SKILLS', 3), ('Estate', 'SKILLS', 1)]
# ____________________________________________________________________________________________________
# Entities [('Shreekumar Das', 'NAME'), ('Regional Sales Manager', 'DESIGNATION'), ('Oracle Corporation\nIndia', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('indeed.com/r/Shreekumar-\nDas/09e7ded65c1d7533', 'EMAIL ADDRESS'), ('23+ years experienced, result', 'YEARS OF EXPERIENCE'), ('Highly skilled in Targeted Account Selling and in devising\n& executing scalable strategies to boost Market Penetration. Adept at driving Business\nGrowth in a wide range of industries with proven expertise in accelerating sales turnover in highly\ncompetitive & continuously evolving markets. Proficient in implementing Go-To-Market\nstrategic plans around Market Segmentation & Competitor Evaluation. Demonstrated\ncapability of liaising with key stakeholders to drive significant gains in profitability & deliver\ncompelling business value to clients.', 'SKILLS'), ('Regional Sales Manager', 'DESIGNATION'), ('Oracle Corporation India', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('October 2012 to Present', 'YEARS OF EXPERIENCE'), ('Country Head - Sales', 'DESIGNATION'), ('Ixsight Technologies', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('July 2010 to August 2012', 'YEARS OF EXPERIENCE'), ('Regional Sales Manager', 'DESIGNATION'), ('Diebold India', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('Sales Head', 'DESIGNATION'), ('SoftDEL Systems', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('December 2006 to June 2008', 'YEARS OF EXPERIENCE'), ('National Manager', 'DESIGNATION'), ('GE Fanuc Systems', 'COMPANIES WORKED AT'), ('November 2004 to December 2006', 'YEARS OF EXPERIENCE'), ('Mumbai', 'LOCATION'), ('November 2000 to December 2006', 'YEARS OF EXPERIENCE'), ('Sales Manager', 'DESIGNATION'), ('GE Fanuc Systems', 'COMPANIES WORKED AT'), ('November 2000 to October 2004', 'YEARS OF EXPERIENCE'), ('B.E. in Industrial Electronics', 'DEGREE'), ('Bharati Vidyapeeth', 'COLLEGE NAME'), ('SALES (10+ years),', 'SKILLS'), ('BUSINESS DEVELOPMENT', 'SKILLS'), ('ACCOUNT MANAGEMENT', 'SKILLS'), ('COMPETITION ANALYSIS', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('Shreekumar', 'NAME', 3), ('Das', 'NAME', 1), ('Regional', 'DESIGNATION', 3), ('Sales', 'DESIGNATION', 1), ('Manager', 'DESIGNATION', 1), ('Oracle', 'COMPANIES WORKED AT', 3), ('Corporation', 'COMPANIES WORKED AT', 1), ('\n', 'COMPANIES WORKED AT', 1), ('India', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('indeed.com', 'EMAIL ADDRESS', 3), ('/', 'EMAIL ADDRESS', 1), ('r', 'EMAIL ADDRESS', 1), ('/', 'EMAIL ADDRESS', 1), ('Shreekumar-', 'EMAIL ADDRESS', 1), ('\n', 'EMAIL ADDRESS', 1), ('Das/09e7ded65c1d7533', 'EMAIL ADDRESS', 1), ('23', 'YEARS OF EXPERIENCE', 3), ('+', 'YEARS OF EXPERIENCE', 1), ('years', 'YEARS OF EXPERIENCE', 1), ('experienced', 'YEARS OF EXPERIENCE', 1), (',', 'YEARS OF EXPERIENCE', 1), ('result', 'YEARS OF EXPERIENCE', 1), ('Highly', 'SKILLS', 3), ('skilled', 'SKILLS', 1), ('in', 'SKILLS', 1), ('Targeted', 'SKILLS', 1), ('Account', 'SKILLS', 1), ('Selling', 'SKILLS', 1), ('and', 'SKILLS', 1), ('in', 'SKILLS', 1), ('devising', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('&', 'SKILLS', 1), ('executing', 'SKILLS', 1), ('scalable', 'SKILLS', 1), ('strategies', 'SKILLS', 1), ('to', 'SKILLS', 1), ('boost', 'SKILLS', 1), ('Market', 'SKILLS', 1), ('Penetration', 'SKILLS', 1), ('.', 'SKILLS', 1), ('Adept', 'SKILLS', 1), ('at', 'SKILLS', 1), ('driving', 'SKILLS', 1), ('Business', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('Growth', 'SKILLS', 1), ('in', 'SKILLS', 1), ('a', 'SKILLS', 1), ('wide', 'SKILLS', 1), ('range', 'SKILLS', 1), ('of', 'SKILLS', 1), ('industries', 'SKILLS', 1), ('with', 'SKILLS', 1), ('proven', 'SKILLS', 1), ('expertise', 'SKILLS', 1), ('in', 'SKILLS', 1), ('accelerating', 'SKILLS', 1), ('sales', 'SKILLS', 1), ('turnover', 'SKILLS', 1), ('in', 'SKILLS', 1), ('highly', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('competitive', 'SKILLS', 1), ('&', 'SKILLS', 1), ('continuously', 'SKILLS', 1), ('evolving', 'SKILLS', 1), ('markets', 'SKILLS', 1), ('.', 'SKILLS', 1), ('Proficient', 'SKILLS', 1), ('in', 'SKILLS', 1), ('implementing', 'SKILLS', 1), ('Go', 'SKILLS', 1), ('-', 'SKILLS', 1), ('To', 'SKILLS', 1), ('-', 'SKILLS', 1), ('Market', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('strategic', 'SKILLS', 1), ('plans', 'SKILLS', 1), ('around', 'SKILLS', 1), ('Market', 'SKILLS', 1), ('Segmentation', 'SKILLS', 1), ('&', 'SKILLS', 1), ('Competitor', 'SKILLS', 1), ('Evaluation', 'SKILLS', 1), ('.', 'SKILLS', 1), ('Demonstrated', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('capability', 'SKILLS', 1), ('of', 'SKILLS', 1), ('liaising', 'SKILLS', 1), ('with', 'SKILLS', 1), ('key', 'SKILLS', 1), ('stakeholders', 'SKILLS', 1), ('to', 'SKILLS', 1), ('drive', 'SKILLS', 1), ('significant', 'SKILLS', 1), ('gains', 'SKILLS', 1), ('in', 'SKILLS', 1), ('profitability', 'SKILLS', 1), ('&', 'SKILLS', 1), ('deliver', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('compelling', 'SKILLS', 1), ('business', 'SKILLS', 1), ('value', 'SKILLS', 1), ('to', 'SKILLS', 1), ('clients', 'SKILLS', 1), ('.', 'SKILLS', 1), ('Regional', 'DESIGNATION', 3), ('Sales', 'DESIGNATION', 1), ('Manager', 'DESIGNATION', 1), ('Oracle', 'COMPANIES WORKED AT', 3), ('Corporation', 'COMPANIES WORKED AT', 1), ('India', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('October', 'YEARS OF EXPERIENCE', 3), ('2012', 'YEARS OF EXPERIENCE', 1), ('to', 'YEARS OF EXPERIENCE', 1), ('Present', 'YEARS OF EXPERIENCE', 1), ('Country', 'DESIGNATION', 3), ('Head', 'DESIGNATION', 1), ('-', 'DESIGNATION', 1), ('Sales', 'DESIGNATION', 1), ('Ixsight', 'COMPANIES WORKED AT', 3), ('Technologies', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('July', 'YEARS OF EXPERIENCE', 3), ('2010', 'YEARS OF EXPERIENCE', 1), ('to', 'YEARS OF EXPERIENCE', 1), ('August', 'YEARS OF EXPERIENCE', 1), ('2012', 'YEARS OF EXPERIENCE', 1), ('Regional', 'DESIGNATION', 3), ('Sales', 'DESIGNATION', 1), ('Manager', 'DESIGNATION', 1), ('Diebold', 'COMPANIES WORKED AT', 3), ('India', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('Sales', 'DESIGNATION', 3), ('Head', 'DESIGNATION', 1), ('SoftDEL', 'COMPANIES WORKED ...
# ____________________________________________________________________________________________________
# Entities [('Nida Khan', 'NAME'), ('Tech Support Executive', 'DESIGNATION'), ('Microsoft', 'COMPANIES WORKED AT'), ('Jaipur', 'LOCATION'), ('indeed.com/r/Nida-Khan/6c9160696f57efd8', 'EMAIL ADDRESS'), ('Tech Support Executive', 'DESIGNATION'), ('Bachelor of Technology in Electronics & communication Engg', 'DEGREE'), ('GNIT institute of Technology', 'COLLEGE'), ('Lucknow', 'LOCATION'), ('2012', 'GRADUATION YEAR'), ('2007', 'GRADUATION YEAR'), ('Microsoft office', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('Nida', 'NAME', 3), ('Khan', 'NAME', 1), ('Tech', 'DESIGNATION', 3), ('Support', 'DESIGNATION', 1), ('Executive', 'DESIGNATION', 1), ('Microsoft', 'COMPANIES WORKED AT', 3), ('Jaipur', 'LOCATION', 3), ('indeed.com/r/Nida-Khan/6c9160696f57efd8', 'EMAIL ADDRESS', 3), ('Tech', 'DESIGNATION', 3), ('Support', 'DESIGNATION', 1), ('Executive', 'DESIGNATION', 1), ('Bachelor', 'DEGREE', 3), ('of', 'DEGREE', 1), ('Technology', 'DEGREE', 1), ('in', 'DEGREE', 1), ('Electronics', 'DEGREE', 1), ('&', 'DEGREE', 1), ('communication', 'DEGREE', 1), ('Engg', 'DEGREE', 1), ('GNIT', 'COLLEGE', 3), ('institute', 'COLLEGE', 1), ('of', 'COLLEGE', 1), ('Technology', 'COLLEGE', 1), ('Lucknow', 'LOCATION', 3), ('2012', 'GRADUATION YEAR', 3), ('2007', 'GRADUATION YEAR', 3), ('Microsoft', 'SKILLS', 3), ('office', 'SKILLS', 1)]
# ____________________________________________________________________________________________________
# Entities [('Shivam Rathi', 'NAME'), ('Microsoft technology Associate (MTA)', 'DESIGNATION'), ('Muzaffarnagar', 'LOCATION'), ('Microsoft technology Associate (MTA)', 'DESIGNATION'), ('C.B.S.E', 'DEGREE'), ('Indraprastha Public School', 'COLLEGE NAME'), ('2012', 'GRADUATION YEAR'), ('B.TECH in Computer Science Engineering', 'DEGREE'), ('Uttrakhand Technical University', 'COLLEGE NAME'), ('C.B.S.E', 'DEGREE'), ('Indraprastha Public School', 'COLLEGE NAME')]
# ____________________________________________________________________________________________________
# Tokens [('Shivam', 'NAME', 3), ('Rathi', 'NAME', 1), ('Microsoft', 'DESIGNATION', 3), ('technology', 'DESIGNATION', 1), ('Associate', 'DESIGNATION', 1), ('(', 'DESIGNATION', 1), ('MTA', 'DESIGNATION', 1), (')', 'DESIGNATION', 1), ('Muzaffarnagar', 'LOCATION', 3), ('Microsoft', 'DESIGNATION', 3), ('technology', 'DESIGNATION', 1), ('Associate', 'DESIGNATION', 1), ('(', 'DESIGNATION', 1), ('MTA', 'DESIGNATION', 1), (')', 'DESIGNATION', 1), ('C.B.S.E', 'DEGREE', 3), ('Indraprastha', 'COLLEGE NAME', 3), ('Public', 'COLLEGE NAME', 1), ('School', 'COLLEGE NAME', 1), ('2012', 'GRADUATION YEAR', 3), ('B.TECH', 'DEGREE', 3), ('in', 'DEGREE', 1), ('Computer', 'DEGREE', 1), ('Science', 'DEGREE', 1), ('Engineering', 'DEGREE', 1), ('Uttrakhand', 'COLLEGE NAME', 3), ('Technical', 'COLLEGE NAME', 1), ('University', 'COLLEGE NAME', 1), ('C.B.S.E', 'DEGREE', 3), ('Indraprastha', 'COLLEGE NAME', 3), ('Public', 'COLLEGE NAME', 1), ('School', 'COLLEGE NAME', 1)]
# ____________________________________________________________________________________________________
# Entities [('Saurabh Saurabh', 'NAME'), ('Bengaluru', 'LOCATION'), ('indeed.com/r/Saurabh-\nSaurabh/87e6b26903460061', 'EMAIL ADDRESS'), ('Anywhere', 'CAN RELOCATE TO'), ('Developer Support Engineer', 'DESIGNATION'), ('Microsoft iGTSC', 'COMPANIES WORKED AT'), ('Certificate of Achievement', 'DEGREE'), ('2016', 'GRADUATION YEAR'), ('C, C++, Data Structure, Java (1 year)', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('Saurabh', 'NAME', 3), ('Saurabh', 'NAME', 1), ('Bengaluru', 'LOCATION', 3), ('indeed.com', 'EMAIL ADDRESS', 3), ('/', 'EMAIL ADDRESS', 1), ('r', 'EMAIL ADDRESS', 1), ('/', 'EMAIL ADDRESS', 1), ('Saurabh-', 'EMAIL ADDRESS', 1), ('\n', 'EMAIL ADDRESS', 1), ('Saurabh/87e6b26903460061', 'EMAIL ADDRESS', 1), ('Anywhere', 'CAN RELOCATE TO', 3), ('Developer', 'DESIGNATION', 3), ('Support', 'DESIGNATION', 1), ('Engineer', 'DESIGNATION', 1), ('Microsoft', 'COMPANIES WORKED AT', 3), ('iGTSC', 'COMPANIES WORKED AT', 1), ('Certificate', 'DEGREE', 3), ('of', 'DEGREE', 1), ('Achievement', 'DEGREE', 1), ('2016', 'GRADUATION YEAR', 3), ('C', 'SKILLS', 3), (',', 'SKILLS', 1), ('C++', 'SKILLS', 1), (',', 'SKILLS', 1), ('Data', 'SKILLS', 1), ('Structure', 'SKILLS', 1), (',', 'SKILLS', 1), ('Java', 'SKILLS', 1), ('(', 'SKILLS', 1), ('1', 'SKILLS', 1), ('year', 'SKILLS', 1), (')', 'SKILLS', 1)]
# ____________________________________________________________________________________________________
# Entities [('Ammit Sharma', 'NAME'), ('General Manager', 'DESIGNATION'), ('Thakkar Stardom Events Pvt. Ltd', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('indeed.com/r/Ammit-Sharma/1ded1fcc57236d58', 'EMAIL ADDRESS'), ('Mumbai', 'LOCATION'), ('General Manager', 'DESIGNATION'), ('Thakkar Stardom Events Pvt. Ltd', 'COMPANIES WORKED AT'), ('Senior Business Development Executive', 'DESIGNATION'), ('JMJ Entertainments Pvt. Ltd', 'COMPANIES WORKED AT'), ('Resolution Expert', 'DESIGNATION'), ('SUTHERLAND GLOBAL SERVICES PVT Ltd', 'COMPANIES WORKED AT'), ('Customer Relationship Advisor', 'DESIGNATION'), ('Customer Relationship Advisor', 'DESIGNATION'), ('ZENTA PVT Ltd', 'COMPANIES WORKED AT'), ('System Engineer', 'DESIGNATION'), ('NEXPRO SOLUTIONS Ltd', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('October 2004 to September 2005', 'YEARS OF EXPERIENCE'), ('Mumbai', 'LOCATION'), ('M.B.A', 'DEGREE'), ('Venkatesh University', 'COLLEGE NAME'), ('Bachelors in Commerce', 'DEGREE'), ('Mumbai', 'LOCATION'), ('Mumbai', 'LOCATION'), ('H.S.C', 'DEGREE'), ('Mumbai', 'LOCATION'), ('Mumbai', 'LOCATION'), ('S.S.C', 'DEGREE'), ('Mumbai', 'LOCATION'), ('Mumbai', 'LOCATION'), ('MICROSOFT WINDOWS', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('Ammit', 'NAME', 3), ('Sharma', 'NAME', 1), ('General', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('Thakkar', 'COMPANIES WORKED AT', 3), ('Stardom', 'COMPANIES WORKED AT', 1), ('Events', 'COMPANIES WORKED AT', 1), ('Pvt', 'COMPANIES WORKED AT', 1), ('.', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('indeed.com/r/Ammit-Sharma/1ded1fcc57236d58', 'EMAIL ADDRESS', 3), ('Mumbai', 'LOCATION', 3), ('General', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('Thakkar', 'COMPANIES WORKED AT', 3), ('Stardom', 'COMPANIES WORKED AT', 1), ('Events', 'COMPANIES WORKED AT', 1), ('Pvt', 'COMPANIES WORKED AT', 1), ('.', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('Senior', 'DESIGNATION', 3), ('Business', 'DESIGNATION', 1), ('Development', 'DESIGNATION', 1), ('Executive', 'DESIGNATION', 1), ('JMJ', 'COMPANIES WORKED AT', 3), ('Entertainments', 'COMPANIES WORKED AT', 1), ('Pvt', 'COMPANIES WORKED AT', 1), ('.', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('Resolution', 'DESIGNATION', 3), ('Expert', 'DESIGNATION', 1), ('SUTHERLAND', 'COMPANIES WORKED AT', 3), ('GLOBAL', 'COMPANIES WORKED AT', 1), ('SERVICES', 'COMPANIES WORKED AT', 1), ('PVT', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('Customer', 'DESIGNATION', 3), ('Relationship', 'DESIGNATION', 1), ('Advisor', 'DESIGNATION', 1), ('Customer', 'DESIGNATION', 3), ('Relationship', 'DESIGNATION', 1), ('Advisor', 'DESIGNATION', 1), ('ZENTA', 'COMPANIES WORKED AT', 3), ('PVT', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('System', 'DESIGNATION', 3), ('Engineer', 'DESIGNATION', 1), ('NEXPRO', 'COMPANIES WORKED AT', 3), ('SOLUTIONS', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('October', 'YEARS OF EXPERIENCE', 3), ('2004', 'YEARS OF EXPERIENCE', 1), ('to', 'YEARS OF EXPERIENCE', 1), ('September', 'YEARS OF EXPERIENCE', 1), ('2005', 'YEARS OF EXPERIENCE', 1), ('Mumbai', 'LOCATION', 3), ('M.B.A', 'DEGREE', 3), ('Venkatesh', 'COLLEGE NAME', 3), ('University', 'COLLEGE NAME', 1), ('Bachelors', 'DEGREE', 3), ('in', 'DEGREE', 1), ('Commerce', 'DEGREE', 1), ('Mumbai', 'LOCATION', 3), ('Mumbai', 'LOCATION', 3), ('H.S.C', 'DEGREE', 3), ('Mumbai', 'LOCATION', 3), ('Mumbai', 'LOCATION', 3), ('S.S.C', 'DEGREE', 3), ('Mumbai', 'LOCATION', 3), ('Mumbai', 'LOCATION', 3), ('MICROSOFT', 'SKILLS', 3), ('WINDOWS', 'SKILLS', 1)]
# ____________________________________________________________________________________________________
# Entities [('Sanjivv Dawalle', 'NAME'), ('Sales Manager', 'DESIGNATION'), ('Quikr India Pvt Ltd', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('indeed.com/r/Sanjivv-Dawalle/\nbe6e06e14054819c', 'EMAIL ADDRESS'), ('Mumbai', 'LOCATION'), ('Mumbai', 'LOCATION'), ('Sales Manager', 'DESIGNATION'), ('Quikr India Pvt Ltd', 'COMPANIES WORKED AT'), ('District Sales Manager', 'DESIGNATION'), ('Getit Infoservices Pvt Ltd', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('Mumbai', 'LOCATION'), ('Area Manager', 'DESIGNATION'), ('Bracecorp Publications Pvt Ltd', 'COMPANIES WORKED AT'), ('Area Sales Manager', 'DESIGNATION'), ('Next Gen Publishing Ltd', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('October 2005 to June 2009', 'YEARS OF EXPERIENCE'), ('Manager', 'DESIGNATION'), ('Mumbai', 'LOCATION'), ('Sr. Sales Executive', 'DESIGNATION'), ('Infocom Network Ltd', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('April 2002 to October 2005', 'YEARS OF EXPERIENCE'), ('B Com', 'DEGREE'), ('Mumbai', 'LOCATION'), ('EXCEL', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('Sanjivv', 'NAME', 3), ('Dawalle', 'NAME', 1), ('Sales', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('Quikr', 'COMPANIES WORKED AT', 3), ('India', 'COMPANIES WORKED AT', 1), ('Pvt', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('indeed.com/r/Sanjivv-Dawalle/', 'EMAIL ADDRESS', 3), ('\n', 'EMAIL ADDRESS', 1), ('be6e06e14054819c', 'EMAIL ADDRESS', 1), ('Mumbai', 'LOCATION', 3), ('Mumbai', 'LOCATION', 3), ('Sales', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('Quikr', 'COMPANIES WORKED AT', 3), ('India', 'COMPANIES WORKED AT', 1), ('Pvt', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('District', 'DESIGNATION', 3), ('Sales', 'DESIGNATION', 1), ('Manager', 'DESIGNATION', 1), ('Getit', 'COMPANIES WORKED AT', 3), ('Infoservices', 'COMPANIES WORKED AT', 1), ('Pvt', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('Mumbai', 'LOCATION', 3), ('Area', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('Bracecorp', 'COMPANIES WORKED AT', 3), ('Publications', 'COMPANIES WORKED AT', 1), ('Pvt', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('Area', 'DESIGNATION', 3), ('Sales', 'DESIGNATION', 1), ('Manager', 'DESIGNATION', 1), ('Next', 'COMPANIES WORKED AT', 3), ('Gen', 'COMPANIES WORKED AT', 1), ('Publishing', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('October', 'YEARS OF EXPERIENCE', 3), ('2005', 'YEARS OF EXPERIENCE', 1), ('to', 'YEARS OF EXPERIENCE', 1), ('June', 'YEARS OF EXPERIENCE', 1), ('2009', 'YEARS OF EXPERIENCE', 1), ('Manager', 'DESIGNATION', 3), ('Mumbai', 'LOCATION', 3), ('Sr', 'DESIGNATION', 3), ('.', 'DESIGNATION', 1), ('Sales', 'DESIGNATION', 1), ('Executive', 'DESIGNATION', 1), ('Infocom', 'COMPANIES WORKED AT', 3), ('Network', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('April', 'YEARS OF EXPERIENCE', 3), ('2002', 'YEARS OF EXPERIENCE', 1), ('to', 'YEARS OF EXPERIENCE', 1), ('October', 'YEARS OF EXPERIENCE', 1), ('2005', 'YEARS OF EXPERIENCE', 1), ('B', 'DEGREE', 3), ('Com', 'DEGREE', 1), ('Mumbai', 'LOCATION', 3), ('EXCEL', 'SKILLS', 3)]
# ____________________________________________________________________________________________________
# Entities [('Ravi Shivgond', 'NAME'), ('Bidar', 'LOCATION'), ('indeed.com/r/Ravi-Shivgond/4018c67548312089', 'EMAIL ADDRESS'), ('Technical Support Engineer', 'DESIGNATION'), ('SAP -', 'COMPANIES WORKED AT'), ('Bengaluru', 'LOCATION'), ('2017', 'GRADUATION YEAR'), ('Govt. High school Yernalli', 'COLLEGE NAME'), ('B.E. in Electrical', 'DEGREE'), ('Bidar', 'LOCATION'), ('AC (Less than 1 year), Allen Bradley (Less than 1 year), Engineer (Less than 1 year), FANUC\n(Less than 1 year), GE FANUC (Less than 1 year)', 'SKILLS'), ('Bidar', 'LOCATION'), ('https://www.indeed.com/r/Ravi-Shivgond/4018c67548312089?isid=rex-download&ikw=download-top&co=IN', 'LINKS')]
# ____________________________________________________________________________________________________
# Tokens [('Ravi', 'NAME', 3), ('Shivgond', 'NAME', 1), ('Bidar', 'LOCATION', 3), ('indeed.com/r/Ravi-Shivgond/4018c67548312089', 'EMAIL ADDRESS', 3), ('Technical', 'DESIGNATION', 3), ('Support', 'DESIGNATION', 1), ('Engineer', 'DESIGNATION', 1), ('SAP', 'COMPANIES WORKED AT', 3), ('-', 'COMPANIES WORKED AT', 1), ('Bengaluru', 'LOCATION', 3), ('2017', 'GRADUATION YEAR', 3), ('Govt', 'COLLEGE NAME', 3), ('.', 'COLLEGE NAME', 1), ('High', 'COLLEGE NAME', 1), ('school', 'COLLEGE NAME', 1), ('Yernalli', 'COLLEGE NAME', 1), ('B.E.', 'DEGREE', 3), ('in', 'DEGREE', 1), ('Electrical', 'DEGREE', 1), ('Bidar', 'LOCATION', 3), ('AC', 'SKILLS', 3), ('(', 'SKILLS', 1), ('Less', 'SKILLS', 1), ('than', 'SKILLS', 1), ('1', 'SKILLS', 1), ('year', 'SKILLS', 1), (')', 'SKILLS', 1), (',', 'SKILLS', 1), ('Allen', 'SKILLS', 1), ('Bradley', 'SKILLS', 1), ('(', 'SKILLS', 1), ('Less', 'SKILLS', 1), ('than', 'SKILLS', 1), ('1', 'SKILLS', 1), ('year', 'SKILLS', 1), (')', 'SKILLS', 1), (',', 'SKILLS', 1), ('Engineer', 'SKILLS', 1), ('(', 'SKILLS', 1), ('Less', 'SKILLS', 1), ('than', 'SKILLS', 1), ('1', 'SKILLS', 1), ('year', 'SKILLS', 1), (')', 'SKILLS', 1), (',', 'SKILLS', 1), ('FANUC', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('(', 'SKILLS', 1), ('Less', 'SKILLS', 1), ('than', 'SKILLS', 1), ('1', 'SKILLS', 1), ('year', 'SKILLS', 1), (')', 'SKILLS', 1), (',', 'SKILLS', 1), ('GE', 'SKILLS', 1), ('FANUC', 'SKILLS', 1), ('(', 'SKILLS', 1), ('Less', 'SKILLS', 1), ('than', 'SKILLS', 1), ('1', 'SKILLS', 1), ('year', 'SKILLS', 1), (')', 'SKILLS', 1), ('Bidar', 'LOCATION', 3), ('https://www.indeed.com/r/Ravi-Shivgond/4018c67548312089?isid=rex-download&ikw=download-top&co=IN', 'LINKS', 3)]
# ____________________________________________________________________________________________________
# Entities [('Riyaz Siddiqui', 'NAME'), ('Mumbai', 'LOCATION'), ('indeed.com/r/Riyaz-Siddiqui/704a6a616556b45d', 'EMAIL ADDRESS'), ('Sales Manager', 'DESIGNATION'), ('Dhruva hiring services, Krishna Sales Corporation, Everest Enterprises.', 'COMPANIES WORKED AT'), ('BCom', 'DEGREE'), ('Mumbai', 'LOCATION'), ('Mumbai', 'LOCATION'), ('BCom', 'DEGREE'), ('Mumbai', 'LOCATION'), ('Manufacturing and trading of scaffolding material', 'SKILLS'), ('https://www.indeed.com/r/Riyaz-Siddiqui/704a6a616556b45d?isid=rex-download&ikw=download-top&co=IN', 'LINKS')]
# ____________________________________________________________________________________________________
# Tokens [('Riyaz', 'NAME', 3), ('Siddiqui', 'NAME', 1), ('Mumbai', 'LOCATION', 3), ('indeed.com/r/Riyaz-Siddiqui/704a6a616556b45d', 'EMAIL ADDRESS', 3), ('Sales', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('Dhruva', 'COMPANIES WORKED AT', 3), ('hiring', 'COMPANIES WORKED AT', 1), ('services', 'COMPANIES WORKED AT', 1), (',', 'COMPANIES WORKED AT', 1), ('Krishna', 'COMPANIES WORKED AT', 1), ('Sales', 'COMPANIES WORKED AT', 1), ('Corporation', 'COMPANIES WORKED AT', 1), (',', 'COMPANIES WORKED AT', 1), ('Everest', 'COMPANIES WORKED AT', 1), ('Enterprises', 'COMPANIES WORKED AT', 1), ('.', 'COMPANIES WORKED AT', 1), ('BCom', 'DEGREE', 3), ('Mumbai', 'LOCATION', 3), ('Mumbai', 'LOCATION', 3), ('BCom', 'DEGREE', 3), ('Mumbai', 'LOCATION', 3), ('Manufacturing', 'SKILLS', 3), ('and', 'SKILLS', 1), ('trading', 'SKILLS', 1), ('of', 'SKILLS', 1), ('scaffolding', 'SKILLS', 1), ('material', 'SKILLS', 1), ('https://www.indeed.com/r/Riyaz-Siddiqui/704a6a616556b45d?isid=rex-download&ikw=download-top&co=IN', 'LINKS', 3)]
# ____________________________________________________________________________________________________
# Entities [('Karthihayini C', 'NAME'), ('Systems Engineer', 'DESIGNATION'), ('Infosys Limited', 'COMPANIES WORKED AT'), ('Rajapalaiyam', 'LOCATION'), ('indeed.com/r/Karthihayini-\nC/627254c443836b3c', 'EMAIL ADDRESS'), ('Anywhere', 'CAN RELOCATE TO'), ('Systems Engineer', 'DESIGNATION'), ('Infosys Limited', 'COMPANIES WORKED AT'), ('Chennai', 'LOCATION'), ('Infosys Limited', 'COMPANIES WORKED AT'), ('2016', 'GRADUATION YEAR'), ('B E in Production Engineering', 'DEGREE'), ('Velammal Engineering College', 'COLLEGE NAME'), ('Destructive Testing', 'SKILLS'), ('FORGE', 'SKILLS'), ('Non-Destructive', 'SKILLS'), ('Non-Destructive Testing', 'SKILLS'), ('quality control', 'SKILLS'), ('Ability to quick grasp the concepts', 'SKILLS'), ('Hard working', 'SKILLS'), ('Consistent', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('Karthihayini', 'NAME', 3), ('C', 'NAME', 1), ('Systems', 'DESIGNATION', 3), ('Engineer', 'DESIGNATION', 1), ('Infosys', 'COMPANIES WORKED AT', 3), ('Limited', 'COMPANIES WORKED AT', 1), ('Rajapalaiyam', 'LOCATION', 3), ('indeed.com', 'EMAIL ADDRESS', 3), ('/', 'EMAIL ADDRESS', 1), ('r', 'EMAIL ADDRESS', 1), ('/', 'EMAIL ADDRESS', 1), ('Karthihayini-', 'EMAIL ADDRESS', 1), ('\n', 'EMAIL ADDRESS', 1), ('C/627254c443836b3c', 'EMAIL ADDRESS', 1), ('Anywhere', 'CAN RELOCATE TO', 3), ('Systems', 'DESIGNATION', 3), ('Engineer', 'DESIGNATION', 1), ('Infosys', 'COMPANIES WORKED AT', 3), ('Limited', 'COMPANIES WORKED AT', 1), ('Chennai', 'LOCATION', 3), ('Infosys', 'COMPANIES WORKED AT', 3), ('Limited', 'COMPANIES WORKED AT', 1), ('2016', 'GRADUATION YEAR', 3), ('B', 'DEGREE', 3), ('E', 'DEGREE', 1), ('in', 'DEGREE', 1), ('Production', 'DEGREE', 1), ('Engineering', 'DEGREE', 1), ('Velammal', 'COLLEGE NAME', 3), ('Engineering', 'COLLEGE NAME', 1), ('College', 'COLLEGE NAME', 1), ('Destructive', 'SKILLS', 3), ('Testing', 'SKILLS', 1), ('FORGE', 'SKILLS', 3), ('Non', 'SKILLS', 3), ('-', 'SKILLS', 1), ('Destructive', 'SKILLS', 1), ('Non', 'SKILLS', 3), ('-', 'SKILLS', 1), ('Destructive', 'SKILLS', 1), ('Testing', 'SKILLS', 1), ('quality', 'SKILLS', 3), ('control', 'SKILLS', 1), ('Ability', 'SKILLS', 3), ('to', 'SKILLS', 1), ('quick', 'SKILLS', 1), ('grasp', 'SKILLS', 1), ('the', 'SKILLS', 1), ('concepts', 'SKILLS', 1), ('Hard', 'SKILLS', 3), ('working', 'SKILLS', 1), ('Consistent', 'SKILLS', 3)]
# ____________________________________________________________________________________________________
# Entities [('Senthil Kumar', 'NAME'), ('Senior Technical Lead', 'DESIGNATION'), ('Cisco', 'COMPANIES WORKED AT'), ('indeed.com/r/Senthil-Kumar/d9d82865dd38d449', 'EMAIL ADDRESS'), ('Senior Technical Lead', 'DESIGNATION'), ('Cisco', 'COMPANIES WORKED AT'), ('Bengaluru', 'LOCATION'), ('2015', 'GRADUATION YEAR'), ('Cisco', 'COMPANIES WORKED AT'), ('Cisco', 'COMPANIES WORKED AT'), ('Cisco', 'COMPANIES WORKED AT'), ('Cisco', 'COMPANIES WORKED AT'), ('Cisco', 'COMPANIES WORKED AT'), ('Cisco', 'COMPANIES WORKED AT'), ('Cisco', 'COMPANIES WORKED AT'), ('Cisco', 'COMPANIES WORKED AT'), ('Technical Lead', 'DESIGNATION'), ('Cisco', 'COMPANIES WORKED AT'), ('Cisco', 'COMPANIES WORKED AT'), ('Cisco', 'COMPANIES WORKED AT'), ('Technical Lead', 'DESIGNATION'), ('Aricent Group', 'COMPANIES WORKED AT'), ('Technical Lead', 'DESIGNATION'), ('Cisco', 'COMPANIES WORKED AT'), ('Cisco', 'COMPANIES WORKED AT'), ('Cisco', 'COMPANIES WORKED AT'), ('Cisco', 'COMPANIES WORKED AT'), ('Chennai', 'LOCATION'), ('B.Tech in Computer Science in Computer Science', 'DEGREE'), ('Dr MGR University Chennai', 'COLLEGE NAME'), ('CPT (3 years), Data Center (4 years), Ethernet (3 years), testing (10+ years), Virtualization (7\nyears)', 'SKILLS'), ('Virtualization VMware-VSphere, DVS, Cisco AVS, Cisco\nACE\n\nSDN Cisco Application Centric Infrastructure\n(ACI)\n\nL2/L3 Protocols OSPF, EIGRP, MPLS, VLAN, VXLAN,\nSTP, RSTP, VPC\n\nMetro Ethernet Protocols Carrier Ethernet protocols EVC, MPLS TP,\nPsudoWire, REP\n\nTraffic Generation Tools Traffic tools IXIA Iexplore and Smart Bit\n\nTesting Tools Wireshark and MIB Browser\n\nNetwork Products Cisco SDN ACI Fabric\nVMWare 5.5 and 6.0\nCisco UCSD Orchestration\nCarrier Ethernet devices (CPT […]\nCisco Metro Ethernet 2600\nCisco routers GSR 12000, 7600\nData center Virtualization using the ACE\nNexus 5k and ACI 9K switches\nCat 6500 and 3550 Switches', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('Senthil', 'NAME', 3), ('Kumar', 'NAME', 1), ('Senior', 'DESIGNATION', 3), ('Technical', 'DESIGNATION', 1), ('Lead', 'DESIGNATION', 1), ('Cisco', 'COMPANIES WORKED AT', 3), ('indeed.com/r/Senthil-Kumar/d9d82865dd38d449', 'EMAIL ADDRESS', 3), ('Senior', 'DESIGNATION', 3), ('Technical', 'DESIGNATION', 1), ('Lead', 'DESIGNATION', 1), ('Cisco', 'COMPANIES WORKED AT', 3), ('Bengaluru', 'LOCATION', 3), ('2015', 'GRADUATION YEAR', 3), ('Cisco', 'COMPANIES WORKED AT', 3), ('Cisco', 'COMPANIES WORKED AT', 3), ('Cisco', 'COMPANIES WORKED AT', 3), ('Cisco', 'COMPANIES WORKED AT', 3), ('Cisco', 'COMPANIES WORKED AT', 3), ('Cisco', 'COMPANIES WORKED AT', 3), ('Cisco', 'COMPANIES WORKED AT', 3), ('Cisco', 'COMPANIES WORKED AT', 3), ('Technical', 'DESIGNATION', 3), ('Lead', 'DESIGNATION', 1), ('Cisco', 'COMPANIES WORKED AT', 3), ('Cisco', 'COMPANIES WORKED AT', 3), ('Cisco', 'COMPANIES WORKED AT', 3), ('Technical', 'DESIGNATION', 3), ('Lead', 'DESIGNATION', 1), ('Aricent', 'COMPANIES WORKED AT', 3), ('Group', 'COMPANIES WORKED AT', 1), ('Technical', 'DESIGNATION', 3), ('Lead', 'DESIGNATION', 1), ('Cisco', 'COMPANIES WORKED AT', 3), ('Cisco', 'COMPANIES WORKED AT', 3), ('Cisco', 'COMPANIES WORKED AT', 3), ('Cisco', 'COMPANIES WORKED AT', 3), ('Chennai', 'LOCATION', 3), ('B.Tech', 'DEGREE', 3), ('in', 'DEGREE', 1), ('Computer', 'DEGREE', 1), ('Science', 'DEGREE', 1), ('in', 'DEGREE', 1), ('Computer', 'DEGREE', 1), ('Science', 'DEGREE', 1), ('Dr', 'COLLEGE NAME', 3), ('MGR', 'COLLEGE NAME', 1), ('University', 'COLLEGE NAME', 1), ('Chennai', 'COLLEGE NAME', 1), ('CPT', 'SKILLS', 3), ('(', 'SKILLS', 1), ('3', 'SKILLS', 1), ('years', 'SKILLS', 1), (')', 'SKILLS', 1), (',', 'SKILLS', 1), ('Data', 'SKILLS', 1), ('Center', 'SKILLS', 1), ('(', 'SKILLS', 1), ('4', 'SKILLS', 1), ('years', 'SKILLS', 1), (')', 'SKILLS', 1), (',', 'SKILLS', 1), ('Ethernet', 'SKILLS', 1), ('(', 'SKILLS', 1), ('3', 'SKILLS', 1), ('years', 'SKILLS', 1), (')', 'SKILLS', 1), (',', 'SKILLS', 1), ('testing', 'SKILLS', 1), ('(', 'SKILLS', 1), ('10', 'SKILLS', 1), ('+', 'SKILLS', 1), ('years', 'SKILLS', 1), (')', 'SKILLS', 1), (',', 'SKILLS', 1), ('Virtualization', 'SKILLS', 1), ('(', 'SKILLS', 1), ('7', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('years', 'SKILLS', 1), (')', 'SKILLS', 1), ('Virtualization', 'SKILLS', 3), ('VMware', 'SKILLS', 1), ('-', 'SKILLS', 1), ('VSphere', 'SKILLS', 1), (',', 'SKILLS', 1), ('DVS', 'SKILLS', 1), (',', 'SKILLS', 1), ('Cisco', 'SKILLS', 1), ('AVS', 'SKILLS', 1), (',', 'SKILLS', 1), ('Cisco', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('ACE', 'SKILLS', 1), ('\n\n', 'SKILLS', 1), ('SDN', 'SKILLS', 1), ('Cisco', 'SKILLS', 1), ('Application', 'SKILLS', 1), ('Centric', 'SKILLS', 1), ('Infrastructure', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('(', 'SKILLS', 1), ('ACI', 'SKILLS', 1), (')', 'SKILLS', 1), ('\n\n', 'SKILLS', 1), ('L2', 'SKILLS', 1), ('/', 'SKILLS', 1), ('L3', 'SKILLS', 1), ('Protocols', 'SKILLS', 1), ('OSPF', 'SKILLS', 1), (',', 'SKILLS', 1), ('EIGRP', 'SKILLS', 1), (',', 'SKILLS', 1), ('MPLS', 'SKILLS', 1), (',', 'SKILLS', 1), ('VLAN', 'SKILLS', 1), (',', 'SKILLS', 1), ('VXLAN', 'SKILLS', 1), (',', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('STP', 'SKILLS', 1), (',', 'SKILLS', 1), ('RSTP', 'SKILLS', 1), (',', 'SKILLS', 1), ('VPC', 'SKILLS', 1), ('\n\n', 'SKILLS', 1), ('Metro', 'SKILLS', 1), ('Ethernet', 'SKILLS', 1), ('Protocols', 'SKILLS', 1), ('Carrier', 'SKILLS', 1), ('Ethernet', 'SKILLS', 1), ('protocols', 'SKILLS', 1), ('EVC', 'SKILLS', 1), (',', 'SKILLS', 1), ('MPLS', 'SKILLS', 1), ('TP', 'SKILLS', 1), (',', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('PsudoWire', 'SKILLS', 1), (',', 'SKILLS', 1), ('REP', 'SKILLS', 1), ('\n\n', 'SKILLS', 1), ('Traffic', 'SKILLS', 1), ('Generation', 'SKILLS', 1), ('Tools', 'SKILLS', 1), ('Traffic', 'SKILLS', 1), ('tools', 'SKILLS', 1), ('IXIA', 'SKILLS', 1), ('Iexplore', 'SKILLS', 1), ('and', 'SKILLS', 1), ('Smart', 'SKILLS', 1), ('Bit', 'SKILLS', 1), ('\n\n', 'SKILLS', 1), ('Testing', 'SKILLS', 1), ('Tools', 'SKILLS', 1), ('W ...
# ____________________________________________________________________________________________________
# ...
# ____________________________________________________________________________________________________
# Entities [('Udayakumar Sampath', 'NAME'), ('Assistant Manager', 'DESIGNATION'), ('SUDAYSHEELA\nCONSULTANCY AND SERVICES PVT LTD', 'COMPANIES WORKED AT'), ('Chennai', 'LOCATION'), ('indeed.com/r/Udayakumar-\nSampath/afb7c1df8ad450b0', 'EMAIL ADDRESS'), ('Tamil Nadu', 'CAN RELOCATE TO'), ('Assistant Manager', 'DESIGNATION'), ('SUDAYSHEELA CONSULTANCY AND SERVICES PVT LTD', 'COMPANIES WORKED AT'), ('Assistant Manager', 'DESIGNATION'), ('Assistant Manager', 'DESIGNATION'), ('MICHELIN INDIA PVT LTD', 'COMPANIES WORKED AT'), ('Administrative and HR Executive', 'DESIGNATION'), ('SKF INDIA LIMITED', 'COMPANIES WORKED AT'), ('Chennai', 'LOCATION'), ('Chennai', 'LOCATION'), ('Administrative and HR Executive', 'DESIGNATION'), ('ORIGIN IT AND FACILITY SOLUTIONS PVT LTD.', 'COMPANIES WORKED AT'), ('Chennai', 'LOCATION'), ('Chennai', 'LOCATION'), ('Administration and HR Assistant', 'DESIGNATION'), ('SYBASE SOLUTIONS PVT LIMITED', 'COMPANIES WORKED AT'), ('Chennai', 'LOCATION'), ('Junior Processor', 'DESIGNATION'), ('LASON INDIA LIMITED', 'COMPANIES WORKED AT'), ('Chennai', 'LOCATION'), ('M A', 'DEGREE'), ("Pachiyappa's College, University of Madras", 'COLLEGE'), ('Chennai', 'LOCATION'), ('B.A.', 'DEGREE'), ('University of Madras', 'COLLEGE'), ('Chennai', 'LOCATION'), ('ACCESS', 'SKILLS'), ('EXCEL', 'SKILLS'), ('MS WORD', 'SKILLS'), ('OUTLOOK', 'SKILLS'), ('POWERPOINT', 'SKILLS'), ('MS Word, Excel, PowerPoint, Access, Outlook, Software testing.', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('Udayakumar', 'NAME', 3), ('Sampath', 'NAME', 1), ('Assistant', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('SUDAYSHEELA', 'COMPANIES WORKED AT', 3), ('\n', 'COMPANIES WORKED AT', 1), ('CONSULTANCY', 'COMPANIES WORKED AT', 1), ('AND', 'COMPANIES WORKED AT', 1), ('SERVICES', 'COMPANIES WORKED AT', 1), ('PVT', 'COMPANIES WORKED AT', 1), ('LTD', 'COMPANIES WORKED AT', 1), ('Chennai', 'LOCATION', 3), ('indeed.com', 'EMAIL ADDRESS', 3), ('/', 'EMAIL ADDRESS', 1), ('r', 'EMAIL ADDRESS', 1), ('/', 'EMAIL ADDRESS', 1), ('Udayakumar-', 'EMAIL ADDRESS', 1), ('\n', 'EMAIL ADDRESS', 1), ('Sampath', 'EMAIL ADDRESS', 1), ('/', 'EMAIL ADDRESS', 1), ('afb7c1df8ad450b0', 'EMAIL ADDRESS', 1), ('Tamil', 'CAN RELOCATE TO', 3), ('Nadu', 'CAN RELOCATE TO', 1), ('Assistant', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('SUDAYSHEELA', 'COMPANIES WORKED AT', 3), ('CONSULTANCY', 'COMPANIES WORKED AT', 1), ('AND', 'COMPANIES WORKED AT', 1), ('SERVICES', 'COMPANIES WORKED AT', 1), ('PVT', 'COMPANIES WORKED AT', 1), ('LTD', 'COMPANIES WORKED AT', 1), ('Assistant', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('Assistant', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('MICHELIN', 'COMPANIES WORKED AT', 3), ('INDIA', 'COMPANIES WORKED AT', 1), ('PVT', 'COMPANIES WORKED AT', 1), ('LTD', 'COMPANIES WORKED AT', 1), ('Administrative', 'DESIGNATION', 3), ('and', 'DESIGNATION', 1), ('HR', 'DESIGNATION', 1), ('Executive', 'DESIGNATION', 1), ('SKF', 'COMPANIES WORKED AT', 3), ('INDIA', 'COMPANIES WORKED AT', 1), ('LIMITED', 'COMPANIES WORKED AT', 1), ('Chennai', 'LOCATION', 3), ('Chennai', 'LOCATION', 3), ('Administrative', 'DESIGNATION', 3), ('and', 'DESIGNATION', 1), ('HR', 'DESIGNATION', 1), ('Executive', 'DESIGNATION', 1), ('ORIGIN', 'COMPANIES WORKED AT', 3), ('IT', 'COMPANIES WORKED AT', 1), ('AND', 'COMPANIES WORKED AT', 1), ('FACILITY', 'COMPANIES WORKED AT', 1), ('SOLUTIONS', 'COMPANIES WORKED AT', 1), ('PVT', 'COMPANIES WORKED AT', 1), ('LTD', 'COMPANIES WORKED AT', 1), ('.', 'COMPANIES WORKED AT', 1), ('Chennai', 'LOCATION', 3), ('Chennai', 'LOCATION', 3), ('Administration', 'DESIGNATION', 3), ('and', 'DESIGNATION', 1), ('HR', 'DESIGNATION', 1), ('Assistant', 'DESIGNATION', 1), ('SYBASE', 'COMPANIES WORKED AT', 3), ('SOLUTIONS', 'COMPANIES WORKED AT', 1), ('PVT', 'COMPANIES WORKED AT', 1), ('LIMITED', 'COMPANIES WORKED AT', 1), ('Chennai', 'LOCATION', 3), ('Junior', 'DESIGNATION', 3), ('Processor', 'DESIGNATION', 1), ('LASON', 'COMPANIES WORKED AT', 3), ('INDIA', 'COMPANIES WORKED AT', 1), ('LIMITED', 'COMPANIES WORKED AT', 1), ('Chennai', 'LOCATION', 3), ('M', 'DEGREE', 3), ('A', 'DEGREE', 1), ('Pachiyappa', 'COLLEGE', 3), ("'s", 'COLLEGE', 1), ('College', 'COLLEGE', 1), (',', 'COLLEGE', 1), ('University', 'COLLEGE', 1), ('of', 'COLLEGE', 1), ('Madras', 'COLLEGE', 1), ('Chennai', 'LOCATION', 3), ('B.A.', 'DEGREE', 3), ('University', 'COLLEGE', 3), ('of', 'COLLEGE', 1), ('Madras', 'COLLEGE', 1), ('Chennai', 'LOCATION', 3), ('ACCESS', 'SKILLS', 3), ('EXCEL', 'SKILLS', 3), ('MS', 'SKILLS', 3), ('WORD', 'SKILLS', 1), ('OUTLOOK', 'SKILLS', 3), ('POWERPOINT', 'SKILLS', 3), ('MS', 'SKILLS', 3), ('Word', 'SKILLS', 1), (',', 'SKILLS', 1), ('Excel', 'SKILLS', 1), (',', 'SKILLS', 1), ('PowerPoint', 'SKILLS', 1), (',', 'SKILLS', 1), ('Access', 'SKILLS', 1), (',', 'SKILLS', 1), ('Outlook', 'SKILLS', 1), (',', 'SKILLS', 1), ('Software', 'SKILLS', 1), ('testing', 'SKILLS', 1), ('.', 'SKILLS', 1)]
# ____________________________________________________________________________________________________
# Entities [('Afreen Jamadar', 'NAME'), ('Sangli', 'LOCATION'), ('indeed.com/r/Afreen-Jamadar/8baf379b705e37c6', 'EMAIL ADDRESS'), ('PG-DAC', 'DEGREE'), ('CDAC ACTS', 'COLLEGE NAME'), ('2017', 'GRADUATION YEAR'), ('Bachelor of Engg in Information Technology', 'DEGREE'), ('Shivaji University Kolhapur', 'COLLEGE NAME'), ('2016', 'GRADUATION YEAR'), ('Database (Less than 1 year), HTML (Less than 1 year), Linux. (Less than 1 year), MICROSOFT\nACCESS (Less than 1 year), MICROSOFT WINDOWS (Less than 1 year)', 'SKILLS'), ('• Programming Languages: C, C++, Java, .net, php.\n• Web Designing: HTML, XML\n• Operating Systems: Windows […] Windows Server 2003, Linux.\n• Database: MS Access, MS SQL Server 2008, Oracle 10g, MySql.', 'SKILLS'), ('https://www.indeed.com/r/Afreen-Jamadar/8baf379b705e37c6?isid=rex-download&ikw=download-top&co=IN', 'LINKS')]
# ____________________________________________________________________________________________________
# Tokens [('Afreen', 'NAME', 3), ('Jamadar', 'NAME', 1), ('Sangli', 'LOCATION', 3), ('indeed.com/r/Afreen-Jamadar/8baf379b705e37c6', 'EMAIL ADDRESS', 3), ('PG', 'DEGREE', 3), ('-', 'DEGREE', 1), ('DAC', 'DEGREE', 1), ('CDAC', 'COLLEGE NAME', 3), ('ACTS', 'COLLEGE NAME', 1), ('2017', 'GRADUATION YEAR', 3), ('Bachelor', 'DEGREE', 3), ('of', 'DEGREE', 1), ('Engg', 'DEGREE', 1), ('in', 'DEGREE', 1), ('Information', 'DEGREE', 1), ('Technology', 'DEGREE', 1), ('Shivaji', 'COLLEGE NAME', 3), ('University', 'COLLEGE NAME', 1), ('Kolhapur', 'COLLEGE NAME', 1), ('2016', 'GRADUATION YEAR', 3), ('Database', 'SKILLS', 3), ('(', 'SKILLS', 1), ('Less', 'SKILLS', 1), ('than', 'SKILLS', 1), ('1', 'SKILLS', 1), ('year', 'SKILLS', 1), (')', 'SKILLS', 1), (',', 'SKILLS', 1), ('HTML', 'SKILLS', 1), ('(', 'SKILLS', 1), ('Less', 'SKILLS', 1), ('than', 'SKILLS', 1), ('1', 'SKILLS', 1), ('year', 'SKILLS', 1), (')', 'SKILLS', 1), (',', 'SKILLS', 1), ('Linux', 'SKILLS', 1), ('.', 'SKILLS', 1), ('(', 'SKILLS', 1), ('Less', 'SKILLS', 1), ('than', 'SKILLS', 1), ('1', 'SKILLS', 1), ('year', 'SKILLS', 1), (')', 'SKILLS', 1), (',', 'SKILLS', 1), ('MICROSOFT', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('ACCESS', 'SKILLS', 1), ('(', 'SKILLS', 1), ('Less', 'SKILLS', 1), ('than', 'SKILLS', 1), ('1', 'SKILLS', 1), ('year', 'SKILLS', 1), (')', 'SKILLS', 1), (',', 'SKILLS', 1), ('MICROSOFT', 'SKILLS', 1), ('WINDOWS', 'SKILLS', 1), ('(', 'SKILLS', 1), ('Less', 'SKILLS', 1), ('than', 'SKILLS', 1), ('1', 'SKILLS', 1), ('year', 'SKILLS', 1), (')', 'SKILLS', 1), ('•', 'SKILLS', 3), ('Programming', 'SKILLS', 1), ('Languages', 'SKILLS', 1), (':', 'SKILLS', 1), ('C', 'SKILLS', 1), (',', 'SKILLS', 1), ('C++', 'SKILLS', 1), (',', 'SKILLS', 1), ('Java', 'SKILLS', 1), (',', 'SKILLS', 1), ('.net', 'SKILLS', 1), (',', 'SKILLS', 1), ('php', 'SKILLS', 1), ('.', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('•', 'SKILLS', 1), ('Web', 'SKILLS', 1), ('Designing', 'SKILLS', 1), (':', 'SKILLS', 1), ('HTML', 'SKILLS', 1), (',', 'SKILLS', 1), ('XML', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('•', 'SKILLS', 1), ('Operating', 'SKILLS', 1), ('Systems', 'SKILLS', 1), (':', 'SKILLS', 1), ('Windows', 'SKILLS', 1), ('[', 'SKILLS', 1), ('…', 'SKILLS', 1), (']', 'SKILLS', 1), ('Windows', 'SKILLS', 1), ('Server', 'SKILLS', 1), ('2003', 'SKILLS', 1), (',', 'SKILLS', 1), ('Linux', 'SKILLS', 1), ('.', 'SKILLS', 1), ('\n', 'SKILLS', 1), ('•', 'SKILLS', 1), ('Database', 'SKILLS', 1), (':', 'SKILLS', 1), ('MS', 'SKILLS', 1), ('Access', 'SKILLS', 1), (',', 'SKILLS', 1), ('MS', 'SKILLS', 1), ('SQL', 'SKILLS', 1), ('Server', 'SKILLS', 1), ('2008', 'SKILLS', 1), (',', 'SKILLS', 1), ('Oracle', 'SKILLS', 1), ('10', 'SKILLS', 1), ('g', 'SKILLS', 1), (',', 'SKILLS', 1), ('MySql', 'SKILLS', 1), ('.', 'SKILLS', 1), ('https://www.indeed.com/r/Afreen-Jamadar/8baf379b705e37c6?isid=rex-download&ikw=download-top&co=IN', 'LINKS', 3)]
# ____________________________________________________________________________________________________
# Entities [('MUKESH SHAH', 'NAME'), ('MARKETING MANAGER', 'DESIGNATION'), ('Mumbai', 'LOCATION'), ('indeed.com/r/MUKESH-SHAH/9f404983c6111dad', 'EMAIL ADDRESS'), ('Mumbai', 'LOCATION'), ('Branch sales Manager', 'DESIGNATION'), ('Erbis Engineering Co. Ltd', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('Sales Manager', 'DESIGNATION'), ('DERE, and PDME', 'COMPANIES WORKED AT'), ('Mumbai', 'LOCATION'), ('Management', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('MUKESH', 'NAME', 3), ('SHAH', 'NAME', 1), ('MARKETING', 'DESIGNATION', 3), ('MANAGER', 'DESIGNATION', 1), ('Mumbai', 'LOCATION', 3), ('indeed.com/r/MUKESH-SHAH/9f404983c6111dad', 'EMAIL ADDRESS', 3), ('Mumbai', 'LOCATION', 3), ('Branch', 'DESIGNATION', 3), ('sales', 'DESIGNATION', 1), ('Manager', 'DESIGNATION', 1), ('Erbis', 'COMPANIES WORKED AT', 3), ('Engineering', 'COMPANIES WORKED AT', 1), ('Co.', 'COMPANIES WORKED AT', 1), ('Ltd', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('Sales', 'DESIGNATION', 3), ('Manager', 'DESIGNATION', 1), ('DERE', 'COMPANIES WORKED AT', 3), (',', 'COMPANIES WORKED AT', 1), ('and', 'COMPANIES WORKED AT', 1), ('PDME', 'COMPANIES WORKED AT', 1), ('Mumbai', 'LOCATION', 3), ('Management', 'SKILLS', 3)]
# ____________________________________________________________________________________________________
# Entities [('Pratik Vaidya', 'NAME'), ('Pune', 'LOCATION'), ('indeed.com/r/Pratik-Vaidya/e88324548608d0bc', 'EMAIL ADDRESS'), ('Mumbai', 'LOCATION'), ('Intern', 'DESIGNATION'), ('Allscripts', 'COMPANIES WORKED AT'), ('2016', 'GRADUATION YEAR'), ('2016', 'GRADUATION YEAR'), ('2016', 'GRADUATION YEAR'), ('Btech', 'DEGREE'), ('Maharashtra Institute of Technology', 'COLLEGE NAME'), ('2016', 'GRADUATION YEAR'), ('Linux', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('Pratik', 'NAME', 3), ('Vaidya', 'NAME', 1), ('Pune', 'LOCATION', 3), ('indeed.com/r/Pratik-Vaidya/e88324548608d0bc', 'EMAIL ADDRESS', 3), ('Mumbai', 'LOCATION', 3), ('Intern', 'DESIGNATION', 3), ('Allscripts', 'COMPANIES WORKED AT', 3), ('2016', 'GRADUATION YEAR', 3), ('2016', 'GRADUATION YEAR', 3), ('2016', 'GRADUATION YEAR', 3), ('Btech', 'DEGREE', 3), ('Maharashtra', 'COLLEGE NAME', 3), ('Institute', 'COLLEGE NAME', 1), ('of', 'COLLEGE NAME', 1), ('Technology', 'COLLEGE NAME', 1), ('2016', 'GRADUATION YEAR', 3), ('Linux', 'SKILLS', 3)]
# ____________________________________________________________________________________________________
# Entities [('Vamsi krishna', 'NAME'), ('hyderbad', 'LOCATION'), ('indeed.com/r/Vamsi-krishna/15906b55159d4088', 'EMAIL ADDRESS'), ('hyderbad', 'LOCATION'), ('Software developer', 'DESIGNATION'), ('Microsoft', 'COMPANIES WORKED AT'), ('Bsc', 'DEGREE'), ('Shri gnanambika degree college', 'COLLEGE NAME'), ('Analytics, Research', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('Vamsi', 'NAME', 3), ('krishna', 'NAME', 1), ('hyderbad', 'LOCATION', 3), ('indeed.com/r/Vamsi-krishna/15906b55159d4088', 'EMAIL ADDRESS', 3), ('hyderbad', 'LOCATION', 3), ('Software', 'DESIGNATION', 3), ('developer', 'DESIGNATION', 1), ('Microsoft', 'COMPANIES WORKED AT', 3), ('Bsc', 'DEGREE', 3), ('Shri', 'COLLEGE NAME', 3), ('gnanambika', 'COLLEGE NAME', 1), ('degree', 'COLLEGE NAME', 1), ('college', 'COLLEGE NAME', 1), ('Analytics', 'SKILLS', 3), (',', 'SKILLS', 1), ('Research', 'SKILLS', 1)]
# ____________________________________________________________________________________________________
# Entities [('VARUN AHLUWALIA', 'NAME'), ('Quantitative Analyst', 'DESIGNATION'), ('indeed.com/r/VARUN-AHLUWALIA/725d9b113f3c4f0c', 'EMAIL ADDRESS'), ('Software Engineer', 'DESIGNATION'), ('Tavant', 'COMPANIES WORKED AT'), ('Software Engineer', 'DESIGNATION'), ('Bangalore', 'LOCATION'), ('Master of Science in Financial Mathematics', 'DEGREE'), ('University of Chicago', 'COLLEGE NAME'), ('2010', 'GRADUATION YEAR'), ('Bachelor of Technology in Civil Engineering', 'DEGREE'), ('Indian Institutes of Technology IIT Kanpur', 'COLLEGE NAME'), ('2004', 'GRADUATION YEAR'), ('Programming • JAVA, C++, C, Matlab, SQL', 'SKILLS'), ('Linux', 'SKILLS')]
# ____________________________________________________________________________________________________
# Tokens [('VARUN', 'NAME', 3), ('AHLUWALIA', 'NAME', 1), ('Quantitative', 'DESIGNATION', 3), ('Analyst', 'DESIGNATION', 1), ('indeed.com/r/VARUN-AHLUWALIA/725d9b113f3c4f0c', 'EMAIL ADDRESS', 3), ('Software', 'DESIGNATION', 3), ('Engineer', 'DESIGNATION', 1), ('Tavant', 'COMPANIES WORKED AT', 3), ('Software', 'DESIGNATION', 3), ('Engineer', 'DESIGNATION', 1), ('Bangalore', 'LOCATION', 3), ('Master', 'DEGREE', 3), ('of', 'DEGREE', 1), ('Science', 'DEGREE', 1), ('in', 'DEGREE', 1), ('Financial', 'DEGREE', 1), ('Mathematics', 'DEGREE', 1), ('University', 'COLLEGE NAME', 3), ('of', 'COLLEGE NAME', 1), ('Chicago', 'COLLEGE NAME', 1), ('2010', 'GRADUATION YEAR', 3), ('Bachelor', 'DEGREE', 3), ('of', 'DEGREE', 1), ('Technology', 'DEGREE', 1), ('in', 'DEGREE', 1), ('Civil', 'DEGREE', 1), ('Engineering', 'DEGREE', 1), ('Indian', 'COLLEGE NAME', 3), ('Institutes', 'COLLEGE NAME', 1), ('of', 'COLLEGE NAME', 1), ('Technology', 'COLLEGE NAME', 1), ('IIT', 'COLLEGE NAME', 1), ('Kanpur', 'COLLEGE NAME', 1), ('2004', 'GRADUATION YEAR', 3), ('Programming', 'SKILLS', 3), ('•', 'SKILLS', 1), ('JAVA', 'SKILLS', 1), (',', 'SKILLS', 1), ('C++', 'SKILLS', 1), (',', 'SKILLS', 1), ('C', 'SKILLS', 1), (',', 'SKILLS', 1), ('Matlab', 'SKILLS', 1), (',', 'SKILLS', 1), ('SQL', 'SKILLS', 1), ('Linux', 'SKILLS', 3)]
# ____________________________________________________________________________________________________
# Saved model to gdrive/My Drive/NLP_Model
# Loading from gdrive/My Drive/NLP_Model
# Predicted entities >
#
# NAME Shivam Rathi
# DESIGNATION Microsoft technology Associate (MTA)
# LOCATION Muzaffarnagar
# DESIGNATION Microsoft technology Associate (MTA)
# DEGREE C.B.S.E
# COLLEGE NAME Indraprastha Public School
# GRADUATION YEAR 2012
# DEGREE B.TECH in Computer Science Engineering
# COLLEGE NAME Uttrakhand Technical University
# DEGREE C.B.S.E
# COLLEGE NAME Indraprastha Public School
#
#
# # of resumes failed to be parsed => 1349
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# Execution completed in =>  01:25:56
